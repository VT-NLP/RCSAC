# %%
import re
import os
import pandas as pd
from io import StringIO
from sklearn.model_selection import train_test_split

# %%
# filename = 'ACAR556.csv'
for filename in os.listdir('./PJ_cleaned/'):
     if '.csv' in filename:
        # print(filename)
        df = pd.read_csv(f'./PJ_cleaned/{filename}', sep='|', header=None)

        new_training_string = ""

        # print(df[2])
        # u_idx = 0
        messages = ["START"]
        for i in range(len(df)):
            if df.iloc[i][0] in filename:
                usr = "groomer"
            else:
                usr = "victim"
            
            msg = df.iloc[i][2]
            # usr = users[u_idx]
            if len(messages) > 10:
                hist = ';;'.join(messages[-10:])
            else:
                hist = ';;'.join(messages)

            if usr == 'groomer':
                new_training_string += f"{hist}|{usr}:{msg}\n"
            messages.append(f'{usr}:{msg}')

            # u_idx = not u_idx
#print(new_training_string)


file = open(f'./groomer_training_data.csv', 'w')
file.writelines(new_training_string)
file.close()

df2 = pd.read_csv('./groomer_training_data.csv', sep='|', header=None)
train, test = train_test_split(df2, test_size=0.1)
test.to_csv('./groomer_test.csv', sep='|')
train.to_csv('./groomer_train.csv', sep='|')

# %%
# filename = 'ACAR556.csv'
for filename in os.listdir('./PJ_cleaned/'):
     if '.csv' in filename:
        # print(filename)
        df = pd.read_csv(f'./PJ_cleaned/{filename}', sep='|', header=None)

        new_training_string = ""

        # print(df[2])
        # u_idx = 0
        messages = ["START"]
        for i in range(1, len(df)):
            if df.iloc[i][0] in filename:
                usr = "groomer"
            else:
                usr = "victim"
            
            msg = df.iloc[i][2]
            # usr = users[u_idx]
            if len(messages) > 10:
                hist = ';;'.join(messages[-10:])
            else:
                hist = ';;'.join(messages)

            if usr == 'victim':
                new_training_string += f"{hist}|{usr}:{msg}\n"
            messages.append(f'{usr}:{msg}')

            # u_idx = not u_idx
#print(new_training_string)


file = open(f'./victim_training_data.csv', 'w')
file.writelines(new_training_string)
file.close()

# %%
df2 = pd.read_csv('./victim_training_data.csv', sep='|', header=None)
df2
# Out:
#                                                       0  \
# 0     START;;groomer:how are you;;groomer:you're a p...
# 1     groomer:how are you;;groomer:you're a poet?;;g...
# 2     groomer:im sure you are a very good poet;;groo...
# 3     groomer:hi zoe;;groomer:hi;;groomer:how old ar...
# 4     groomer:hi zoe;;victim:hiya!;;groomer:im glad ...
# ...                                                 ...
# 1410  victim:kewl;;victim:im excitd!;;groomer:why?;;...
# 1411  groomer:why?;;victim:idk shuld i not b?;;groom...
# 1412  victim:y?;;groomer:never done this before;;vic...
# 1413  victim:well at least ill b able 2 tell ur not ...
# 1414  victim:yah lol;;groomer:ok i'll ttyl;;victim:k...
#
#                                                       1
# 0                                          victim:hiya!
# 1       victim:yah i got some offlines from u last nite
# 2                                          victim:wa u?
# 3     victim:o u ment city...im from sorta around *e...
# 4                     victim:yah sorta but im bad at it
# ...                                                 ...
# 1410                                     victim:yah lol
# 1411  victim:kk im gonna go take a shower an look pr...
# 1412                                       victim:byeee
# 1413              victim:well duh if its 11 ill b there
# 1414                                     victim:kk bye!
#
# [1415 rows x 2 columns]

# %%
train, test = train_test_split(df2, test_size=0.1)
test.to_csv('./victim_test.csv', sep='|')
train.to_csv('./victim_train.csv', sep='|')
